# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('data.csv')
df
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...

# %%
features = ['danceability', 'loudness', 'speechiness','valence','acousticness','energy','instrumentalness','liveness','tempo']  
X = df[features]
X
# Out:
#         danceability  loudness  speechiness  valence  acousticness  energy  \
# 0              0.279   -20.096       0.0366   0.0594       0.98200   0.211
# 1              0.819   -12.441       0.4150   0.9630       0.73200   0.341
# 2              0.328   -14.850       0.0339   0.0394       0.96100   0.166
# 3              0.275    -9.316       0.0354   0.1650       0.96700   0.309
# 4              0.418   -10.096       0.0380   0.2530       0.95700   0.193
# ...              ...       ...          ...      ...           ...     ...
# 170648         0.786    -3.702       0.0881   0.6080       0.08460   0.808
# 170649         0.717    -6.020       0.0605   0.7340       0.20600   0.753
# 170650         0.634    -2.226       0.0809   0.6370       0.10100   0.858
# 170651         0.671    -7.161       0.3080   0.1950       0.00998   0.623
# 170652         0.856    -4.928       0.1080   0.6420       0.13200   0.721
#
#         instrumentalness  liveness    tempo
# ...

# %%
import h5py
from sklearn.metrics.pairwise import cosine_similarity

def compute_and_save_cosine_similarity_h5(X, batch_size=1000, output_file='cosine_sim_matrix.h5'):
    num_samples = X.shape[0]
    
    with h5py.File(output_file, 'w') as f:
        # Create a dataset to store the cosine similarity matrix
        dset = f.create_dataset('cosine_similarity', (num_samples, num_samples), dtype=np.float32)
        
        for i in range(0, num_samples, batch_size):
            end_i = min(i + batch_size, num_samples)
            for j in range(i, num_samples, batch_size):
                end_j = min(j + batch_size, num_samples)
                batch_i = X[i:end_i]
                batch_j = X[j:end_j]
                
                # Compute cosine similarity for the batch
                cos_sim_batch = cosine_similarity(batch_i, batch_j)
                
                # Store results in dataset
                dset[i:end_i, j:end_j] = cos_sim_batch

compute_and_save_cosine_similarity_h5(X)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[19], line 22, in compute_and_save_cosine_similarity_h5(X, batch_size, output_file)
#      21 # Store results in dataset
# ---> 22 dset[i:end_i, j:end_j] = cos_sim_batch
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\h5py\_hl\dataset.py:999, in Dataset.__setitem__(self, args, val)
#     998 for fspace in selection.broadcast(mshape):
# --> 999     self.id.write(mspace, fspace, val, mtype, dxpl=self._dxpl)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5d.pyx:282, in h5py.h5d.DatasetID.write()
#
# File h5py\\_proxy.pyx:115, in h5py._proxy.dset_rw()
#
# ...
