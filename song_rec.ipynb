# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('data.csv')
df = df[df['year'] >= 2000]
df = df.reset_index(drop=True)
df
# Out:
#        valence  year  acousticness  \
# 0        0.285  2000       0.00239
# 1        0.613  2000       0.14300
# 2        0.400  2000       0.00958
# 3        0.543  2000       0.00664
# 4        0.760  2000       0.03020
# ...        ...   ...           ...
# 41445    0.608  2020       0.08460
# 41446    0.734  2020       0.20600
# 41447    0.637  2020       0.10100
# 41448    0.195  2020       0.00998
# 41449    0.642  2020       0.13200
#
#                                                  artists  danceability  \
# 0                                           ['Coldplay']         0.429
# 1                                            ['OutKast']         0.843
# 2                                        ['Linkin Park']         0.556
# 3                                       ['3 Doors Down']         0.545
# 4                                             ['Eminem']         0.949
# ...                                                  ...           ...
# 41445  ['Anuel AA', 'Daddy Yankee', 'KAROL G', 'Ozuna...         0.786
# 41446                                       ['Ashnikko']         0.717
# 41447                                        ['MAMAMOO']         0.634
# 41448                                         ['Eminem']         0.671
# 41449                              ['KEVVO', 'J Balvin']         0.856
#
#        duration_ms  energy  explicit                      id  \
# 0           266773   0.661         0  3AJwUDP919kvQ9QcozQPxg
# 1           270507   0.806         1  0I3q5fE6wg7LIfHGngUTnV
# 2           216880   0.864         0  60a0Rd6pjrkxjPbaKzXjfq
# 3           233933   0.865         0  6ZOBP3NvffbU4SZcrnt1k6
# 4           284200   0.661         1  3yfqSUWxFvZELEM4PmlwIR
# ...            ...     ...       ...                     ...
# 41445       301714   0.808         0  0KkIkfsLEJbrcIhYsCL7L5
# 41446       150654   0.753         0  0OStKKAuXlxA0fMH54Qs6E
# 41447       211280   0.858         0  4BZXVFYCb76Q0Klojq4piV
# 41448       337147   0.623         1  5SiZJoLXp3WOl3J4C8IK0d
# 41449       189507   0.721         1  7HmnJHfs0BkFzX4x8j0hkl
#
#        instrumentalness  key  liveness  loudness  mode  \
# 0              0.000121   11    0.2340    -7.227     1
# 1              0.000000    4    0.0771    -5.946     0
# 2              0.000000    3    0.2090    -5.870     0
# 3              0.000011   11    0.1680    -5.708     0
# 4              0.000000    5    0.0454    -4.244     0
# ...                 ...  ...       ...       ...   ...
# 41445          0.000289    7    0.0822    -3.702     1
# 41446          0.000000    7    0.1010    -6.020     1
# 41447          0.000009    4    0.2580    -2.226     0
# 41448          0.000008    2    0.6430    -7.161     1
# 41449          0.004710    7    0.1820    -4.928     1
#
#                                   name  popularity release_date  speechiness  \
# 0                               Yellow          84   2000-07-10       0.0281
# 1                          Ms. Jackson          80   2000-10-31       0.2690
# 2                           In the End          84   2000-10-24       0.0584
# 3                           Kryptonite          78         2000       0.0286
# 4                  The Real Slim Shady          80   2000-05-23       0.0572
# ...                                ...         ...          ...          ...
# 41445                            China          72   2020-05-29       0.0881
# 41446      Halloweenie III: Seven Days          68   2020-10-23       0.0605
# 41447                              AYA          76   2020-11-03       0.0809
# 41448                         Darkness          70   2020-01-17       0.3080
# 41449  Billetes Azules (with J Balvin)          74   2020-10-16       0.1080
#
#          tempo
# 0      173.372
# 1       94.948
# 2      105.143
# 3       99.009
# 4      104.504
# ...        ...
# 41445  105.029
# 41446  137.936
# 41447   91.688
# 41448   75.055
# 41449   94.991
#
# [41450 rows x 19 columns]

# %%
features = ['danceability', 'loudness', 'speechiness','valence','acousticness','energy','instrumentalness','liveness','tempo']  
X = df[features]
X
# Out:
#        danceability  loudness  speechiness  valence  acousticness  energy  \
# 0             0.429    -7.227       0.0281    0.285       0.00239   0.661
# 1             0.843    -5.946       0.2690    0.613       0.14300   0.806
# 2             0.556    -5.870       0.0584    0.400       0.00958   0.864
# 3             0.545    -5.708       0.0286    0.543       0.00664   0.865
# 4             0.949    -4.244       0.0572    0.760       0.03020   0.661
# ...             ...       ...          ...      ...           ...     ...
# 41445         0.786    -3.702       0.0881    0.608       0.08460   0.808
# 41446         0.717    -6.020       0.0605    0.734       0.20600   0.753
# 41447         0.634    -2.226       0.0809    0.637       0.10100   0.858
# 41448         0.671    -7.161       0.3080    0.195       0.00998   0.623
# 41449         0.856    -4.928       0.1080    0.642       0.13200   0.721
#
#        instrumentalness  liveness    tempo
# 0              0.000121    0.2340  173.372
# 1              0.000000    0.0771   94.948
# 2              0.000000    0.2090  105.143
# 3              0.000011    0.1680   99.009
# 4              0.000000    0.0454  104.504
# ...                 ...       ...      ...
# 41445          0.000289    0.0822  105.029
# 41446          0.000000    0.1010  137.936
# 41447          0.000009    0.2580   91.688
# 41448          0.000008    0.6430   75.055
# 41449          0.004710    0.1820   94.991
#
# [41450 rows x 9 columns]

# %%
import h5py
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

def compute_and_save_cosine_similarity_h5(X, batch_size=1000, output_file='cosine_sim_matrix.h5'):
    num_samples = X.shape[0]
    
    with h5py.File(output_file, 'w') as f:
        dset = f.create_dataset('cosine_similarity', (num_samples, num_samples), dtype=np.float32, compression='gzip', compression_opts=9)
        
        for i in range(0, num_samples, batch_size):
            end_i = min(i + batch_size, num_samples)
            for j in range(i, num_samples, batch_size):
                end_j = min(j + batch_size, num_samples)
                batch_i = X[i:end_i]
                batch_j = X[j:end_j]
                
                cos_sim_batch = cosine_similarity(batch_i, batch_j)
                
                dset[i:end_i, j:end_j] = cos_sim_batch

compute_and_save_cosine_similarity_h5(X)

# %%
df_search=df.copy()
df_search['name'] = df['name'] + ' ' + df['artists']
df_search.head()
# Out:
#    valence  year  acousticness           artists  danceability  duration_ms  \
# 0    0.285  2000       0.00239      ['Coldplay']         0.429       266773
# 1    0.613  2000       0.14300       ['OutKast']         0.843       270507
# 2    0.400  2000       0.00958   ['Linkin Park']         0.556       216880
# 3    0.543  2000       0.00664  ['3 Doors Down']         0.545       233933
# 4    0.760  2000       0.03020        ['Eminem']         0.949       284200
#
#    energy  explicit                      id  instrumentalness  key  liveness  \
# 0   0.661         0  3AJwUDP919kvQ9QcozQPxg          0.000121   11    0.2340
# 1   0.806         1  0I3q5fE6wg7LIfHGngUTnV          0.000000    4    0.0771
# 2   0.864         0  60a0Rd6pjrkxjPbaKzXjfq          0.000000    3    0.2090
# 3   0.865         0  6ZOBP3NvffbU4SZcrnt1k6          0.000011   11    0.1680
# 4   0.661         1  3yfqSUWxFvZELEM4PmlwIR          0.000000    5    0.0454
#
#    loudness  mode                            name  popularity release_date  \
# 0    -7.227     1             Yellow ['Coldplay']          84   2000-07-10
# 1    -5.946     0         Ms. Jackson ['OutKast']          80   2000-10-31
# 2    -5.870     0      In the End ['Linkin Park']          84   2000-10-24
# 3    -5.708     0     Kryptonite ['3 Doors Down']          78         2000
# 4    -4.244     0  The Real Slim Shady ['Eminem']          80   2000-05-23
#
#    speechiness    tempo      normalized_name
# 0       0.0281  173.372               yellow
# 1       0.2690   94.948          ms. jackson
# 2       0.0584  105.143           in the end
# 3       0.0286   99.009           kryptonite
# 4       0.0572  104.504  the real slim shady

# %%
import pandas as pd
import difflib

def get_closest_song(song_name, df):
    song_name = song_name.lower().strip()
    df['normalized_name'] = df['name'].str.lower().str.strip()
    list_of_all_titles = df['normalized_name'].tolist()
    find_close_matches = difflib.get_close_matches(song_name, list_of_all_titles)
    
    if not find_close_matches:
        print('No match found')
        return None
    
    print("\nSimilar songs:")
    similar_titles = df[df['normalized_name'].isin(find_close_matches)]
    
    for i, name in enumerate(find_close_matches):
        matching_rows = similar_titles[similar_titles['normalized_name'] == name]
        for index, row in matching_rows.iterrows():
            print(f"{i}: {row['name']} by {row['artists']}")
            break  
    
    try:
        choice = int(input(f"Enter your choice number (0 to {len(find_close_matches) - 1}): "))
        if 0 <= choice < len(find_close_matches):
            chosen_name = find_close_matches[choice]
            chosen_song = similar_titles[similar_titles['normalized_name'] == chosen_name]
            chosen_song_info = chosen_song[['name', 'artists']].iloc[0]
            return chosen_song_info
        else:
            print("Invalid choice")
            return None
    except ValueError:
        print("Invalid input. Please enter a number.")
        return None



song_name = input('Enter your favourite song name: ')
chosen_song_info = get_closest_song(song_name, df)
if chosen_song_info is not None:
    print(f"You selected: {chosen_song_info['name']} by {chosen_song_info['artists']}")
search_name=chosen_song_info['name'] +' '+ chosen_song_info['artists']
print(search_name)
# Out:
# Similar songs:
# 0: goosebumps by ['Travis Scott']
# 1: goosebumps by ['Travis Scott']
# 2: Goosebumps Theme by ['Retrospectre']
# You selected: goosebumps by ['Travis Scott']
# goosebumps ['Travis Scott']

# %%
import h5py

with h5py.File('cosine_sim_matrix.h5', 'r') as f:
    cos_sim_matrix = f['cosine_similarity']
    matching_index = df_search[df_search['name'] == search_name].index[0]
    similarity_scores = cos_sim_matrix[matching_index:matching_index + 1]
    index_score_pairs = [(i, similarity_scores[0, i]) for i in range(similarity_scores.shape[1])]

# %%
sorted_index_score_pairs = sorted(index_score_pairs, key=lambda x: x[1], reverse=True)

# %%
for i in range(0,30):
    index=sorted_index_score_pairs[i][0]
    print(df_search.iloc[index,14])
# Out:
# goosebumps ['Travis Scott']
# IDOL ['BTS']
# Estamos Arriba ['Bad Bunny', 'Myke Towers']
# El Punto Final ['Conjunto Atardecer', 'Montez de Durango']
# Smiling Faces ['Kevin Gates']
# D.A.M. ['Fetty Wap']
# Heavy ['Gucci Mane']
# Heavy ['Gucci Mane']
# Dan Bilzerian (feat. Lil Yachty) ['T-Pain', 'Lil Yachty']
# King Sh*t (feat. T.I.) ['Yo Gotti', 'T.I.']
# Trap (feat. Lil Baby) ['SAINt JHN', 'Lil Baby']
# We Still in this Bitch (feat. T.I. and Juicy J) ['B.o.B', 'T.I.', 'Juicy J']
# Modern Slavery ['Huncho Jack', 'Travis Scott', 'Quavo']
# Everybody Mad ['O.T. Genasis']
# Facts (Charlie Heat Version) ['Kanye West']
# Fool ['Fitz and The Tantrums']
# The Days ['Avicii']
# Slow Burn ['Doomtree']
# Let Me See (feat. Kevin Gates & Lil Skies) ['Juicy J', 'Kevin Gates', 'Lil Skies']
# Tu Direccion ['Los Inquietos Del Norte']
# I'm So Hood ['DJ Khaled', 'T-Pain', 'Rick Ross', 'Plies', 'Trick Daddy']
# Dream Glow (BTS World Original Soundtrack) - Pt. 1 ['BTS', 'Charli XCX']
# FANTASTIC BABY - Japanese ver. ['BIGBANG']
# Summit (feat. Ellie Goulding) ['Skrillex', 'Ellie Goulding']
# Big Booty (feat. Megan Thee Stallion) ['Gucci Mane', 'Megan Thee Stallion']
# White Tee - Alternate Bass Boosted Version ['CORPSE']
# Kiss the Girl ['Ashley Tisdale']
# Big Booty (feat. Megan Thee Stallion) ['Gucci Mane', 'Megan Thee Stallion']
# Bad Chick ['SoMo']
# He Chose Me ['Too $hort', 'Ms. Hollywood', 'The Up All Nite Crew']
